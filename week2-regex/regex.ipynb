# %% [markdown]
# ### Regular expressions

# %% [markdown]
# Regular expressions (regex) are patterns which match parts of text. Optionally, they can also replace. They are powerful ways of finding and changing strings.
#
# The most important point is that regular expressions are not specific to Python. They're ubiquitous in programming and usually available in any piece of software that works with sequences of characters.

# %% [markdown]
# Data preparation is a large part of most DH projects. Regex is a key tool, whatever your software or programming language. Learn regex once: use everywhere!

# %% [markdown]
# Regex has limitations. We'll come back to the at the end, but regex only works with strings. In regex, the number _5_ is a string, not an integer. That means that you can find sequences of numbers but with regex alone you can't increment those numbers or do other mathematical operations on them.
#
# Fortunately a programming language can do that. So if you combine regex with something like Python you can have the best of both.

# %% [markdown]
# Let's read in _Persuasion_ again, as we did last week. Make sure it's in the same folder as this notebook, or add a path that points to it:

# %%
with open('persuasion.txt', 'r', encoding="utf-8") as f:
    persuasion = f.read()

# %% [markdown]
# Last week we had a really awkward way of looking for the context in which 'Anne' occurs:

# %%
persuasion.find("Anne")
# Out:
# 2133

# %%
persuasion[2113:2153]
# Out:
# ' born\nJune 1, 1785; Anne, born August 9,'

# %% [markdown]
# To get the next occurrence we'd have to look in the slice after 2133 (note that parts of a slice can be omitted).

# %%
persuasion[2153:].find("Anne")
# Out:
# 4320

# %% [markdown]
# But...

# %%
persuasion[4300:4340]
# Out:
# 'ealed his failings, and promoted his rea'

# %% [markdown]
# We could programmatically loop through the text and look for the string we want in each fragment. Here's an approach to splitting the text in Python, using a ```while``` loop. But this is getting complicated immediately.

# %%
offset = 0
while offset < 1000:
    persuasion_chunk = persuasion[offset:offset + 100]
    print(f"{offset}:{offset + 100}") # show the chunk range
    print(persuasion_chunk)
    offset += 100
    #print("finished")
# Out:
# 0:100
# ﻿The Project Gutenberg eBook of Persuasion
#
# This ebook is for the use of anyone anywhere in the
# 100:200
# United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoeve
# 200:300
# r. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License inclu
# 300:400
# ded with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you
# 400:500
#  will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: P
# 500:600
# ersuasion
#
# Author: Jane Austen
#
# Release date: February 1, 1994 [eBook #105]
#                 Most rec
# 600:700
# ently updated: September 10, 2023
#
# Language: English
#
# Credits: Sharon Partridge and Martin Ward
#
# 700:800
#     Revised by Richard Tonsing.
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK PERSUASION ***
#
#
#
#
# Persua
# 800:900
# sion
#
#
# by Jane Austen
#
# (1818)
#
#
#
#
# Contents
#
#
#  CHAPTER I.
#  CHAPTER II.
#  CHAPTER III.
#  CHAPTER IV.
#  CH
# 900:1000
# APTER V.
#  CHAPTER VI.
#  CHAPTER VII.
#  CHAPTER VIII.
#  CHAPTER IX.
#  CHAPTER X.
#  CHAPTER XI.
#  CHAPTER XI
# finished

# %% [markdown]
# We're only looking for literal strings so we can't ask for the context around a string like _Anne_ because we don't know in advance what that context is. This is where _regular expressions_, also called _regex_ can help.
#
# First we need to import Python's ```re``` module. It's part of the standard library so it will be installed in any normal installation of Python.

# %%
import re

# %% [markdown]
# Now we can use regex, in which some characters are _literal_ and some are _special_. Nearly every regex has a combination of both.
#
# But let's start just by running up a regex that only looks for the literal string _Anne_. Note that, because we imported the whole ```re``` library, we have to refer to ```re.findall```, not just ```findall```.
#
# We'll read the results into a variable called ```anne_context```.

# %%
anne_context = re.findall(r"Anne", persuasion)

# %% [markdown]
# The results are now held in ```anne_context```.

# %%
anne_context
# Out:
# ['Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne']

# %% [markdown]
# A key special character in regex is ```.``` and it means _any character_ so we can add this either side of our literal _Anne_ string to get the context, eg 10 characters either side.

# %%
anne_context = re.findall(r"..........Anne..........", persuasion)
anne_context
# Out:
# [' 1, 1785; Anne, born Aug',
#  'rove; but Anne, with an ',
#  's only in Anne that she ',
#  's before, Anne Elliot ha',
#  ' growing. Anne haggard, ',
#  'father of Anne and her s',
#  'dation of Anne’s had bee',
#  ' on which Anne wanted he',
#  'ntry. All Anne’s wishes ',
#  'l fate of Anne attended ',
#  ' her dear Anne’s known w',
#  'bourhood. Anne herself w',
#  'regard to Anne’s dislike',
#  'What Miss Anne says, is ',
#  'lace; and Anne, after th',
#  'hed, than Anne, who had ',
#  'think of! Anne Elliot, s',
#  'ths ended Anne’s share o',
#  're, while Anne was ninet',
#  'his case, Anne had left ',
#  'sness for Anne’s being t',
#  ' point of Anne’s conduct',
#  'd to; but Anne, at seven',
#  'ent could Anne Elliot ha',
#  'nced that Anne would not',
#  'shed, and Anne though dr',
#  ' claiming Anne when anyt',
#  'o without Anne,” was Mar',
#  'I am sure Anne had bette',
#  ' all; and Anne, glad to ',
#  'tled that Anne should no',
#  'tained to Anne, in Mrs C',
#  'se, while Anne could be ',
#  '” replied Anne, “which a',
#  'lves, and Anne walked up',
#  'ther, and Anne was set d',
#  '; and, on Anne’s appeari',
#  '” replied Anne. “You sen',
#  '” replied Anne, cheerful',
#  'r me. Oh! Anne, I am so ',
#  's abroad. Anne always co',
#  'rally, as Anne very well',
#  'ame time, Anne could bel',
#  'etimes to Anne’s admirat',
#  ' am sure, Anne, if you w',
#  'lone with Anne, to say, ',
#  '“Oh! Miss Anne, I cannot',
#  'you, Miss Anne, it preve',
#  'ou_, Miss Anne, because ',
#  'here; and Anne, very muc',
#  'ame back. Anne had very ',
#  'd humour. Anne gave her ',
#  ' week, in Anne’s reckoni',
#  'ress, and Anne had every',
#  'ught; and Anne, in the j',
#  ', indeed, Anne. I will g',
#  'y kind of Anne,” was her',
#  'rushed on Anne, of which',
#  'ared, and Anne might fin',
#  't by you, Anne, though h',
#  'owledge.” Anne fully sub',
#  ' forgiven Anne Elliot. S',
#  'nice; and Anne Elliot wa',
#  'worth and Anne Elliot we',
#  'he spoke, Anne felt the ',
#  ' reminded Anne of the ea',
#  '“Ah! Miss Anne, if it ha',
#  'bout me.” Anne’s shudder',
#  'convinced Anne, that ins',
#  'ations of Anne’s slender',
#  'nd bow to Anne), “beyond',
#  'proposed, Anne offered h',
#  ' occupied Anne, while he',
#  'as far as Anne’s observa',
#  'd Mary to Anne, as soon ',
#  'n seen by Anne; but she ',
#  'lone with Anne Elliot, d',
#  ' had been Anne’s reply, ',
#  'een them. Anne longed fo',
#  'o-morrow. Anne could onl',
#  'ech. What Anne first hea',
#  'surprised Anne if Louisa',
#  'd married Anne instead. ',
#  'persuaded Anne to refuse',
#  'ting, and Anne distingui',
#  ' business Anne could not',
#  'de, while Anne was never',
#  'h as made Anne suspect t',
#  'ixed; and Anne, being en',
#  'es, Mary, Anne, Henriett',
#  'et,” said Anne to hersel',
#  'lay, that Anne felt her ',
#  ' so many. Anne had a mom',
#  'musing to Anne; connecte',
#  't fell to Anne’s lot to ',
#  'was over, Anne could not',
#  'ou think, Anne, it is be',
#  'y passed, Anne’s face ca',
#  'hing like Anne Elliot ag',
#  ' inn; and Anne, in passi',
#  'e person. Anne felt that',
#  'ng roused Anne’s curiosi',
#  ' Charles, Anne, must not',
#  ' with us! Anne, must not',
#  'oes. But, Anne, only con',
#  'ttention, Anne quietly t',
#  'No,” said Anne, “that I ',
#  'nwick and Anne, who caug',
#  'm,” cried Anne, “for hea',
#  'entworth, Anne, or Charl',
#  's manner, Anne walking b',
#  'entworth, Anne was sure ',
#  'int, when Anne, coming q',
#  'n; but if Anne will stay',
#  'nstead of Anne; Anne, wh',
#  'useful as Anne? And to g',
#  ' Mary for Anne was inevi',
#  'eption of Anne; or must ',
#  'motion to Anne, she quit',
#  ' on fast. Anne was aston',
#  'ast hill, Anne found her',
#  'ainder of Anne’s time at',
#  't without Anne, it would',
#  'way, that Anne thought s',
#  'ion, that Anne was delig',
#  'ith them, Anne would hav',
#  ' by both. Anne was consc',
#  'lue of an Anne Elliot, s',
#  'ir way to Anne, she coul',
#  'her soon. Anne, have you',
#  'h moments Anne had no po',
#  'd brought Anne the last ',
#  'delighted Anne. His good',
#  'danger to Anne of meetin',
#  'oing than Anne conceived',
#  'urning to Anne). “He fan',
#  'o believe Anne a greater',
#  'm mention Anne twice all',
#  ' declare, Anne, he never',
#  'ntance of Anne’s will al',
#  ' to being Anne’s acquain',
#  'ry,” said Anne. “I think',
#  '“So do I, Anne,” said Ch',
#  'h, though Anne hazarded ',
#  'ssell and Anne were both',
#  'ssell and Anne paid thei',
#  'f course. Anne had alway',
#  'od, which Anne could not',
#  'nt. Could Anne wonder th',
#  'liot too. Anne had a gre',
#  'ary); and Anne, smiling ',
#  'ctions to Anne alone: he',
#  'int which Anne, on retur',
#  '“now Miss Anne was come,',
#  'est, that Anne was not s',
#  ' morning, Anne and her f',
#  'appear to Anne that the ',
#  'r, and of Anne so overlo',
#  'ars since Anne had begun',
#  're, which Anne, after a ',
#  ' In fact, Anne could nev',
#  'mples (in Anne’s opinion',
#  ' and when Anne ventured ',
#  'ir value. Anne smiled an',
#  ',” sighed Anne, “we shal',
#  'll,” said Anne, “I certa',
#  'ra Place, Anne was renew',
#  'valuable. Anne had gone ',
#  'mith, and Anne therefore',
#  'dings, as Anne chose to ',
#  'd changed Anne from the ',
#  'all this, Anne had reaso',
#  'aven; and Anne viewed he',
#  'ning, and Anne was alrea',
#  'o is Miss Anne Elliot to',
#  'ord, Miss Anne Elliot, y',
#  '” replied Anne; “on the ',
#  'd of Miss Anne Elliot, a',
#  'room, and Anne could hav',
#  'rits; and Anne could not',
#  'g to gain Anne in time a',
#  ' speak to Anne with half',
#  'im,” said Anne; “but we ',
#  'y dearest Anne, it would',
#  ' This, to Anne, was a de',
#  'uary; and Anne, having b',
#  'int which Anne had not b',
#  ' farther, Anne ventured ',
#  'ity which Anne could not',
#  'walk with Anne, and expr',
#  'next time Anne walked ou',
#  'ifle, and Anne was most ',
#  'than Miss Anne’s; and, i',
#  'Elliot as Anne could be,',
#  'is cousin Anne’s boots w',
#  'int, when Anne, as she s',
#  'eard, and Anne continuin',
#  't grieved Anne to observ',
#  ' again to Anne, and by m',
#  ' I think; Anne Elliot; v',
#  'g morning Anne was out w',
#  'aged; and Anne, wearied ',
#  'in alone. Anne was the n',
#  'upport to Anne; she knew',
#  'reddening Anne’s cheeks ',
#  'ther; and Anne who, in s',
#  '” replied Anne; “but whe',
#  'abeth and Anne Elliot as',
#  'each; and Anne—but it wo',
#  'nature of Anne’s felicit',
#  'g of Miss Anne Elliot; a',
#  'n of Miss Anne Elliot as',
#  'e name of Anne Elliot,” ',
#  'is point, Anne’s eyes ha',
#  't of tea. Anne was one o',
#  ' however. Anne sometimes',
#  ' her own, Anne was enabl',
#  'r obliged Anne to turn r',
#  ' be sung. Anne could not',
#  'or?” said Anne, suddenly',
#  'ath, than Anne was sport',
#  're,” said Anne, consciou',
#  'verspread Anne’s cheeks.',
#  ' repeated Anne, looking ',
#  '” replied Anne; “but I s',
#  '” replied Anne, “nor nex',
#  'No,” said Anne, “I can r',
#  'yond; and Anne, eager to',
#  'continued Anne, presentl',
#  'ay,” said Anne, “I have ',
#  's,” cried Anne, struck b',
#  'e,” cried Anne. “You hav',
#  't putting Anne in a glow',
#  ', as Miss Anne Elliot, a',
#  'ment; but Anne had not a',
#  'es,” said Anne, “you tel',
#  'is,” said Anne, after a ',
#  'tion, and Anne had forgo',
#  'band; but Anne could col',
#  'nity; and Anne felt, at ',
#  'dulgence. Anne could per',
#  'to engage Anne’s good of',
#  ' interest Anne’s feeling',
#  'r Elliot, Anne could not',
#  'ter, Miss Anne, seems be',
#  's towards Anne. “Exactly',
#  ' his; and Anne would hav',
#  'miration, Anne could not',
#  'd,” cried Anne, “particu',
#  'hina; but Anne had heard',
#  'ning; and Anne walked of',
#  'ity which Anne delighted',
#  'rcel; and Anne had not b',
#  'o,” cried Anne, quickly,',
#  'self, but Anne did not m',
#  '“Do come, Anne,” cried M',
#  'entworth. Anne will not ',
#  's life to Anne, who saw ',
#  'sing Miss Anne, too, if ',
#  'd,” cried Anne, and stop',
#  's left to Anne’s imagina',
#  ' to move. Anne talked of',
#  'tant; but Anne could ima',
#  'sed since Anne’s convers',
#  ' whisper. Anne felt that',
#  'sensibly. Anne hoped the',
#  'tion, but Anne heard not',
#  'ndow, and Anne seeming t',
#  '” replied Anne, in a low',
#  'ue,” said Anne, “very tr',
#  '” replied Anne, “but the',
#  'down; but Anne was start',
#  'miling at Anne), “well s',
#  'h!” cried Anne eagerly, ',
#  ' be gone. Anne knew not ',
#  'it before Anne with eyes',
#  'd made in Anne, was almo',
#  'ecaution, Anne struggled',
#  'give Miss Anne’s message',
#  'y looked. Anne could com',
#  ' and give Anne your arm ',
#  '” replied Anne. “You sho',
#  'ht,” said Anne, “that my',
#  'ction for Anne, and no v',
#  ' Russell. Anne knew that',
#  'She loved Anne better th',
#  'y keeping Anne with her ',
#  'in seeing Anne restored ',
#  'is cousin Anne’s engagem',
#  'ffices by Anne had been ',
#  'er heart. Anne was tende']

# %% [markdown]
# What are we getting back from Python here? Is it a string? How can we check?

# %% [markdown]
# Because this turns out to be a list, we can use slicing again. For example to get the last mentions of Anne in _Persuasion_ we can do this:

# %%
anne_context[-5:]
# Out:
# ['y keeping Anne with her ',
#  'in seeing Anne restored ',
#  'is cousin Anne’s engagem',
#  'ffices by Anne had been ',
#  'er heart. Anne was tende']

# %% [markdown]
# If you're ever unsure about the syntax for lists, create a small list of your own to check your intuition.

# %%
mylist = [1, 2, 3, 4, 5, 6]
mylist[-5:]
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# With the regex, we can always add or subtract more full points to get more or less context.
#
# But there is a problem with the results of the regex. Since this is a list, we can get its length:

# %%
len(anne_context)
# Out:
# 291

# %%
persuasion.count("Anne")
# Out:
# 496

# %% [markdown]
# These kinds of sense checks are good to build in to your thinking, and your code, as much as possible.

# %% [markdown]
# The next special character we'll use is ```?```, meaning _one or none_ of the preceding characters.

# %% [markdown]
# If we're not sure of the spelling of _Anne_ we can now allow for _Ann_ as well

# %%
anne_context = re.findall(r"..........Anne?..........", persuasion)

# %% [markdown]
# We can also use ```[^]``` to ask for any characters other than the ones after the ```^``` symbol.

# %%
no_anne_context = re.findall(r".......Ann[^e]+......", persuasion)

# %%
no_anne_context
# Out:
# []

# %% [markdown]
# But we can also use this to make the characters around our string option. This is pretty crude but let's do it anyway:

# %%
anne_context = re.findall(r".?.?.?.?.?.?.?.?Anne.?.?.?.?.?.?.?.?.?.?", persuasion)

# %%
len(anne_context)
# Out:
# 494

# %% [markdown]
# A much better way is to give a range of how many characters we want to match, using ```{``` and ```}```.

# %%
anne_context = re.findall(r".{0,20}Anne.{0,20}", persuasion)

# %%
len(anne_context)
# Out:
# 493

# %% [markdown]
# We're still missing three...

# %% [markdown]
# Last week we weren't sure if there were characters called _Annette_ or places called _Annecy_ in the text. With regex we can check that. Let's look for _A_ followed by any number of lower-case letters.
#
# Square brackets represent a _character class_, meaning _any one of these in any order_. ```[a-z]``` is a convenience to save you from typing ```[abcdefghijklmnopqrstuvwxyz]``` every time.
#
# ```+``` is like the ```?``` we saw above, but it means _one or more_.

# %%
capital_a = re.findall(r"A[a-z]+", persuasion)
capital_a
# Out:
# ['Author',
#  'Austen',
#  'Austen',
#  'Anne',
#  'August',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'Anne',
#  'Always',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'After',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'And',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'And',
#  'Admiral',
#  'At',
#  'After',
#  'Anne',
#  'As',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'An',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Accordingly',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Again',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'And',
#  'And',
#  'And',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Are',
#  'An',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Alas',
#  'And',
#  'Anne',
#  'Altered',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anybody',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Ah',
#  'Anne',
#  'Anne',
#  'Asp',
#  'Asp',
#  'Admiralty',
#  'Admiral',
#  'Asp',
#  'Admiral',
#  'Asp',
#  'Ah',
#  'Asp',
#  'Asp',
#  'Anne',
#  'And',
#  'Ah',
#  'And',
#  'Ah',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'All',
#  'Anne',
#  'All',
#  'Ah',
#  'Admiral',
#  'Ay',
#  'Atlantic',
#  'And',
#  'Admiral',
#  'Aye',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'And',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Another',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Admiral',
#  'Ah',
#  'Admiral',
#  'And',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Ay',
#  'And',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Abydos',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Ah',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Ay',
#  'And',
#  'August',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'An',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'An',
#  'Anne',
#  'As',
#  'Admiral',
#  'Ay',
#  'Admiral',
#  'Anne',
#  'Another',
#  'Ay',
#  'And',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'And',
#  'Any',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Allowances',
#  'All',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'As',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Are',
#  'And',
#  'And',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'And',
#  'Admiral',
#  'Archibald',
#  'Ah',
#  'Archibald',
#  'Anne',
#  'Admiral',
#  'As',
#  'Anne',
#  'Ay',
#  'Anne',
#  'An',
#  'Anne',
#  'Admiral',
#  'And',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'After',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'After',
#  'Anne',
#  'As',
#  'Atkinson',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Another',
#  'Anne',
#  'At',
#  'Alicia',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'All',
#  'Anne',
#  'After',
#  'Anne',
#  'About',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'An',
#  'Anne',
#  'All',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'After',
#  'Anne',
#  'Are',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'As',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'At',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'And',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Alicia',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Alarming',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Ah',
#  'And',
#  'Anne',
#  'All',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anything',
#  'And',
#  'Anne',
#  'Anxious',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Another',
#  'Anne',
#  'Are',
#  'Are',
#  'Anne',
#  'And',
#  'All',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'All',
#  'An',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Archive',
#  'Additional',
#  'Any',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'About',
#  'Archive']

# %%
capital_a.sort()
capital_a
# Out:
# ['About',
#  'About',
#  'Abydos',
#  'Accordingly',
#  'Additional',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiralty',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'Again',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Alarming',
#  'Alas',
#  'Alicia',
#  'Alicia',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'Allowances',
#  'Altered',
#  'Always',
#  'An',
#  'An',
#  'An',
#  'An',
#  'An',
#  'An',
#  'An',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Another',
#  'Another',
#  'Another',
#  'Another',
#  'Anxious',
#  'Any',
#  'Any',
#  'Anybody',
#  'Anything',
#  'Archibald',
#  'Archibald',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Are',
#  'Are',
#  'Are',
#  'Are',
#  'Are',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'Asp',
#  'Asp',
#  'Asp',
#  'Asp',
#  'Asp',
#  'Asp',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'Atkinson',
#  'Atlantic',
#  'August',
#  'August',
#  'Austen',
#  'Austen',
#  'Author',
#  'Ay',
#  'Ay',
#  'Ay',
#  'Ay',
#  'Ay',
#  'Ay',
#  'Aye']

# %%
set(capital_a)
# Out:
# {'About',
#  'Abydos',
#  'Accordingly',
#  'Additional',
#  'Admiral',
#  'Admiralty',
#  'After',
#  'Again',
#  'Ah',
#  'Alarming',
#  'Alas',
#  'Alicia',
#  'All',
#  'Allowances',
#  'Altered',
#  'Always',
#  'An',
#  'And',
#  'Anne',
#  'Another',
#  'Anxious',
#  'Any',
#  'Anybody',
#  'Anything',
#  'Archibald',
#  'Archive',
#  'Are',
#  'As',
#  'Asp',
#  'At',
#  'Atkinson',
#  'Atlantic',
#  'August',
#  'Austen',
#  'Author',
#  'Ay',
#  'Aye'}

# %% [markdown]
# So there are, apparently, characters called _Alicia_, _Archibald_ and _Atkinson_.

# %%
len(set(capital_a))
# Out:
# 37

# %% [markdown]
# Can we use regex to look at all the verbs associated with Anne in _Persuasion_? Here's a first attempt:

# %%
annes_verbs = re.findall(r"Anne [^ ]+ed\W", persuasion)

# %%
annes_verbs
# Out:
# ['Anne admired ',
#  'Anne attended ',
#  'Anne avoided ',
#  'Anne conceived ',
#  'Anne convinced ',
#  'Anne delighted ',
#  'Anne distinguished ',
#  'Anne enquired ',
#  'Anne entered ',
#  'Anne felt\npersuaded,',
#  'Anne followed ',
#  'Anne hazarded ',
#  'Anne hoped ',
#  'Anne hoped ',
#  'Anne included ',
#  'Anne listened,',
#  'Anne longed ',
#  'Anne looked ',
#  'Anne mentioned ',
#  'Anne named ',
#  'Anne offered ',
#  'Anne presumed,',
#  'Anne recollected ',
#  'Anne restored ',
#  'Anne sighed ',
#  'Anne smiled ',
#  'Anne smiled ',
#  'Anne smiled,',
#  'Anne struggled,',
#  'Anne suppressed ',
#  'Anne talked ',
#  'Anne ventured ',
#  'Anne ventured ',
#  'Anne viewed ',
#  'Anne walked ',
#  'Anne walked ',
#  'Anne walked ',
#  'Anne wanted ',
#  'Anne wondered ']

# %% [markdown]
# These aren't, of course, all of Anne's verbs. Regex only operates on sequences of characters.

# %% [markdown]
# We've now seen quite a lot of the regex syntax you'll ever need to find things with. To sum up:
#
# ```.``` any character
#
# ```+``` one or more of the preceding (by default, matches as much as possible: 'greedy')
#
# ```?``` one or none of the preceding
#
# ```*``` one or none of the preceding (by default, matches as much as possible: 'greedy')
#
# ```[]``` a character class, 'find any of these, in any order'
#
# ```[^]``` a negated character class 'find anything that is not one of these'
#
# What about if you want to find literal versions of the above, like a literal full stop?
#
# Put a ```\``` in front of it to _escape_ it: make it not special. For example ```\?``` matches a literal question mark.
#
# #### some shortcuts
#
# ```\w``` any non-whitespace character
#
# ```\W``` any whitespace character, including punctuation
#
# ```[0-9]``` any number
#
# ```[a-z]``` any lowercase letter
#
# ```[A-Z]``` any uppercase letter

# %% [markdown]
# But if you're new to regex this will still be a lot to take in. Practice is the only way to learning regex, so don't worry. The key thing is to remember that there are many situations where regex will make your life easier and you can look up the syntax any time you need to.

# %% [markdown]
# Last week, splitting on whitespace was too crude for us to get all the words from _Persuasion_. Regex allows us to fix that.

# %%
persuasion_words = re.findall(r'\w+', persuasion)

# %%
biggest_words = sorted(persuasion_words, key=len, reverse=True)

# %%
biggest_words[:10]

# %%
from collections import Counter

# %%
mycounts = Counter(persuasion_words)
mycounts.most_common(10) # or whatever number required

# %% [markdown]
# What about replacing? For that, in Python, we use ```re.sub```. It works the same way as ```findall``` but we need an extra argument to the function: the thing we want to put in place of what we found. As always, the simplest possible example is a good place to start.

# %%
sample = "Anne Elliot"
print(sample)
sample = re.sub(r"Anne? El+iot+", "the principal character", sample)
print(sample)
# Out:
# Anne Elliot
# the principal character

# %% [markdown]
# The most powerful part of replacement is re-using parts of the find, for example to add to them or move them around.
#
# To do this, put round brackets around a part of the regex you want to recall in the replacement, this is known as a _capture group_.
#
# In the replacement text the contents of the first set of brackets are referred to with ```\\1```, the second set as ```\\2``` and so on. In regex this is known as a _back reference_.

# %%
sample = "Anne Elliot"
print(sample)
print("But let's swap the names around:")
sample = re.sub(r"(Anne?) (El+iot+)", "\\2, \\1", sample)
print(sample)
# Out:
# Anne Elliot
# But let's swap the names around:
# Elliot, Anne

# %% [markdown]
# When not to use regular expressions.
#
# Because regex work on strings, they cannot reliably _parse_ data, that is work with its structure.
#
# Once you get good at regex, you might be tempted to use it to parse structured data. Here's a simple example of data in _CSV_ (_comma-separated values_) format:
# ```
# character,novel,occurence_count
# Anne Elliot,Persuasion,486
# Emma Woodhouse,Emma,397
# Elizabeth Bennett,Pride and Prejudice,292
# Fanny Price,Mansfield Park,331
# ```
#
# If you try to extract the middle column you will be trying to parse the data with regex. This is highly unreliable and inadvisable.

# %% [markdown]
# ### Group work

# %% [markdown]
# #### finding
#
# 1. Find the context around another main character in _Persuasion_, Captain Wentworth.
#
# 2. Does Captain ever get abbreviated to _Capt._?
#
# 3. Find the word following _Anne_. Can you make a unique list of these? Can you take account of punctuation between _Anne_ and the following word?
#
# 4. Can you create an alphabetised list of all 9-letter words in _Persuasion_?
#
# 5. By default in Python, a ```.``` won't run past a ```\n``` character. Can you modify one of the above searches to include characters from the next line? You might need to look at the ```re``` (https://docs.python.org/3/library/re.html)[documentation] for the answer to this.
#
# #### replacing
#
# Use ```re.sub``` to replace some text in ```persuasion```. If you work on the whole novel, Python will have no trouble with this, but it might be hard to see the results. You might prefer to create a slice of Persuasion of a few hundred characters, so you can see the output of your replacement more easily.
#
# This will overwrite the text of ```persuasion```, so if you prefer you can create a string with a different variable name, eg:
#
# ```modified_persuasion = re.sub(r"search string", "replacement", persuasion)```
#
#
# #### finally
#
# Can you explain why, above, we got slightly more results for ```persuasion.count("Anne")```, when compared to ```re.findall(r"{0,20}Anne{0,20}, persuasion)```? This is a bit tricky! Maybe create a small text of your own to test the way these two behave.
